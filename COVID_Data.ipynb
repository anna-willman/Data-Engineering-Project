# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import requests
from jsonmerge import merge
from pprint import pprint
import pandas as pd
from pandas.io.json import json_normalize
import json
import io

pd.set_option('display.max_columns', None)

# %%
url="http://covidtracking.com/api/states/daily.csv"
s=requests.get(url).content

# %%
covid_df = pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
# format
covid_df = pd.read_csv(io.StringIO(s.decode('utf-8')))
covid_df['date'] =  pd.to_datetime(covid_df['date'], format='%Y%m%d')
covid_df.drop(['dateChecked'],axis=1,inplace=True)
covid_df['state']=covid_df['state'].apply(str)
covid_df.fillna(value=-1, inplace=True)

# %%
# filter to NV only
nv_covid_df = covid_df[covid_df['state'] == 'NV']

# %%
nv_covid_df.head(5)
# Out:
#           date state  positive  probableCases  negative  pending  \
# 36  2020-12-03    NV  159532.0           -1.0  839656.0     -1.0
# 92  2020-12-02    NV  156996.0           -1.0  834431.0     -1.0
# 148 2020-12-01    NV  154867.0           -1.0  831889.0     -1.0
# 204 2020-11-30    NV  152169.0           -1.0  827680.0     -1.0
# 260 2020-11-29    NV  150527.0           -1.0  824769.0     -1.0
#
#        totalTestResultsSource  totalTestResults  hospitalizedCurrently  \
# 36   totalTestEncountersViral         1682758.0                 1645.0
# 92   totalTestEncountersViral         1664999.0                 1652.0
# 148  totalTestEncountersViral         1653858.0                 1589.0
# 204  totalTestEncountersViral         1638099.0                 1545.0
# 260  totalTestEncountersViral         1627306.0                 1460.0
#
#      hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 36                     -1.0           373.0             -1.0
# ...

# %%
rel_cols = ['date',
'state',
'positive',
'negative',
'totalTestResults',
'hospitalizedCurrently',
'inIcuCurrently',
'onVentilatorCurrently',
'death',
'lastUpdateEt',
'dateModified']
nv_covid_df_rel = nv_covid_df[rel_cols]
nv_covid_df_rel
# Out:
#             date state  positive  negative  totalTestResults  \
# 36    2020-12-03    NV  159532.0  839656.0         1682758.0
# 92    2020-12-02    NV  156996.0  834431.0         1664999.0
# 148   2020-12-01    NV  154867.0  831889.0         1653858.0
# 204   2020-11-30    NV  152169.0  827680.0         1638099.0
# 260   2020-11-29    NV  150527.0  824769.0         1627306.0
# 316   2020-11-28    NV  149229.0  823887.0         1622816.0
# 372   2020-11-27    NV  146317.0  819428.0         1607005.0
# 428   2020-11-26    NV  144781.0  814412.0         1592915.0
# 484   2020-11-25    NV  142239.0  808477.0         1574257.0
# 540   2020-11-24    NV  139080.0  804646.0         1558626.0
# 596   2020-11-23    NV  136227.0  797361.0         1536076.0
# 652   2020-11-22    NV  133888.0  791926.0         1520545.0
# 708   2020-11-21    NV  131733.0  787646.0         1507064.0
# 764   2020-11-20    NV  129714.0  776680.0         1478163.0
# ...

# %%
nv_covid_df_rel.isnull().values.any()
# Out:
# False

# %%
nv_covid_df_rel.to_csv(r'C:\Users\willm\OneDrive\Documents\MSCA\31012 - Data Engineering\Final_Project\Datasets\Yelp\NV_COVIDdata_1204.csv')

# %%
nv_covid_df_rel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274 entries, 36 to 15243
# Data columns (total 11 columns):
# date                     274 non-null datetime64[ns]
# state                    274 non-null object
# positive                 274 non-null float64
# negative                 274 non-null float64
# totalTestResults         274 non-null float64
# hospitalizedCurrently    274 non-null float64
# inIcuCurrently           274 non-null float64
# onVentilatorCurrently    274 non-null float64
# death                    274 non-null float64
# lastUpdateEt             274 non-null object
# dateModified             274 non-null object
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 25.7+ KB
